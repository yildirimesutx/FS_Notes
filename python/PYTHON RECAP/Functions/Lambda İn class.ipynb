# %%
lambda x : "odd" if x % 2 != 0 else "even"
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x : "odd" if x % 2 != 0 else "even")(2)
# Out:
# 'even'

# %%
(lambda x : "odd" if x % 2 != 0 else "even")(3)
# Out:
# 'odd'

# %%
number = [1,2,3,4]

(lambda x : x[::-1])(number)
# Out:
# [4, 3, 2, 1]

# %%
(lambda a, b : (a+b)/2)(3 ,5)
# Out:
# 4.0

# %%
liste = [1, 2, 3, 4, 5, 6]

task = map(lambda x : "odd" if x % 2 != 0 else "even", liste)

print(*task)
# Out:
# odd even odd even odd even

# %%
sayılar = [1, 2, 3, 4, 5, 6]

for a in sayılar :
    print(a, ":", (lambda x : "odd" if x % 2 != 0 else "even")(a))
# Out:
# 1 : odd
# 2 : even
# 3 : odd
# 4 : even
# 5 : odd
# 6 : even

# %%
finder = lambda x : "odd" if x % 2 != 0 else "even"

# %%
print(finder(5))
# Out:
# odd

# %%
reverser = lambda x : x[::-1]

print(reverser("clarusway"))
# Out:
# yawsuralc

# %%
fonksiyon = lambda x : x**2
iterable = [1, 2, 3]

# %%
sonuc = map(fonksiyon, iterable)
print(*sonuc)
# Out:
# 1 4 9

# %%
def kare(b) :
    return b**2

# %%
sonuc2 = map(kare, iterable)
print(*sonuc2)
# Out:
# 1 4 9

# %%
topla = lambda x, y, z : x + y + z

# %%
topla("a", "l","i")
# Out:
# 'ali'

# %%
num1 = [9, 6, 7, 4]
num2 = [3, 6, 5, 8]

# %%
func = lambda x, y : (x + y) / 2

# %%
numbers = map(func, num1, num2)

# %%
print(list(numbers))
# Out:
# [6.0, 6.0, 6.0, 6.0]

# %%
words1 = ["you", "much", "hard"]
words2 = ["i", "you", "he"]
words3 = ["love", "ate", "works"]

func = lambda x, y, z : x + " " + y + " " +z

words = map(func, words2, words3, words1)

print(list(words))
# Out:
# ['i love you', 'you ate much', 'he works hard']

# %%
words = ["apple", "swim", "clock", "me", "kiwi", "banana"]

task = filter(lambda x : len(x) < 5, words)

print(*task)
# Out:
# swim me kiwi

# %%
words = ["apple", "swim", "clock", "me", "kiwi", "banana"]

for i in filter(lambda x : len(x) < 5, words) :
      print(i)
# Out:
# swim
# me
# kiwi

# %%
vowel_list = ['a', 'e', 'i', 'o', 'u']
first_ten = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
"a" in vowel_list
# Out:
# True

# %%
"b" in vowel_list
# Out:
# False

# %%
vowels = filter(lambda x : x in vowel_list, first_ten)
print(list(vowels))
# Out:
# ['a', 'e', 'i']

# %%
def modular(n) :
    return lambda x : x ** n

# %%
karesinial = modular(2)

# %%
karesinial(3)
# Out:
# 9

# %%
kupunual = modular(3)

# %%
kupunual(9)
# Out:
# 729

# %%
def smile(n):
    return lambda x : x +  ":)"
# Out:
#   File "C:\Users\Mete\AppData\Local\Temp/ipykernel_15272/3407829292.py", line 2
#     return lambda x : x +  :)
#                            ^
# SyntaxError: invalid syntax

# %%
task = smile("Hello")

# %%
print(list(task))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15272/2344476212.py in <module>
# ----> 1 print(list(task))
#
# TypeError: 'function' object is not iterable

# %%
(lambda x : print(x, ":)"))("ali")
# Out:
# ali :)

# %%
(lambda x : print(x, ":("))("ali")
# Out:
# ali :(

# %%
(lambda x : print(x, ":|"))("ali")
# Out:
# ali :|

# %%
def functioner(emoji) :
    return lambda x : print(x, emoji)

# %%
myPrint_smile = functioner(":)")
myPrint_sad = functioner(":(")
myPrint_neutral = functioner(":|")

# %%
myPrint_sad("hello")
# Out:
# hello :(

# %%
def function_generator(function_name) :
    return lambda x : function_name(x)

# %%
#mesut_print() --> print()
#mesut_max()  --> max()
#mesut_bool()  --> bool()
#mesut_sorted() --> sorted()

# %%
(lambda x : print(x))("ali veli deli")
# Out:
# ali veli deli

# %%
(lambda x : max(x))((1, 2, 3))
# Out:
# 3

# %%
mesut_max = function_generator(max)
mesut_sorted = function_generator(sorted)

# %%
mesut_max((2,33,78))
# Out:
# 78
